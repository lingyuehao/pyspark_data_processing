# %% [markdown]
# # **PySpark Data Processing Assignment**

# %% [markdown]
# ## 1. Data Processing **Pipeline**

# %% [markdown]
# ### Load data:

# %%
# Load table
table_name = "default.individual_incident_2020"   
df = spark.table(table_name)

# Basic info
print("Rows:", df.count(), "Cols:", len(df.columns))
df.printSchema()
display(df.limit(5))
# Out:
# Rows: 9130711 Cols: 53
# root
#  |-- state: string (nullable = true)
#  |-- ID: string (nullable = true)
#  |-- ORI: string (nullable = true)
#  |-- incident_number: string (nullable = true)
#  |-- date_HRF: long (nullable = true)
#  |-- date_SIF: string (nullable = true)
#  |-- hour: string (nullable = true)
#  |-- total_offense: long (nullable = true)
#  |-- total_victim: long (nullable = true)
#  |-- total_offender: long (nullable = true)
#  |-- violence_offense: long (nullable = true)
#  |-- theft_offense: long (nullable = true)
#  |-- drug_offense: long (nullable = true)
#  |-- sex_offense: long (nullable = true)
#  |-- kidnapping_trafficking: long (nullable = true)
#  |-- other_offense: long (nullable = true)
#  |-- gun_involvement: long (nullable = true)
#  |-- drug_involvement: long (nullable = true)
#  |-- property_value: long (nullable = true)
#  |-- stolen_motor: long (nullable = true)
#  |-- male_victim: long (nullable = true)
#  |-- female_victim: long (nullable = true)
#  |-- unknown_sex_victim: long (nullable = true)
#  |-- w_victim: long (nullable = true)
#  |-- b_victim: long (nullable = true)
#  |-- i_victim: long (nullable = true)
#  |-- a_victim: long (nullable = true)
#  |-- p_victim: long (nullable = true)
#  |-- unknown_race_victim: long (nullable = true)
#  |-- minor_victim: long (nullable = true)
#  |-- non_minor_victim: long (nullable = true)
#  |-- unknown_age_victim: long (nullable = true)
#  |-- offender_wi_family: long (nullable = true)
#  |-- offender_outside_family: long (nullable = true)
#  |-- offender_not_known: long (nullable = true)
#  |-- male_offender: long (nullable = true)
#  |-- female_offender: long (nullable = true)
#  |-- unknown_sex_offender: long (nullable = true)
#  |-- w_offender: long (nullable = true)
#  |-- b_offender: long (nullable = true)
#  |-- i_offender: long (nullable = true)
#  |-- a_offender: long (nullable = true)
#  |-- p_offender: long (nullable = true)
#  |-- unknown_race_offender: long (nullable = true)
#  |-- minor_offender: long (nullable = true)
#  |-- non_minor_offender: long (nullable = true)
#  |-- unknown_age_offender: long (nullable = true)
#  |-- completed_attempted2: string (nullable = true)
#  |-- completed_attempted3: string (nullable = true)
#  |-- property_description: string (nullable = true)
#  |-- property_description2: string (nullable = true)
#  |-- property_description3: string (nullable = true)
#  |-- race_offender2: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>state</th><th>ID</th><th>ORI</th><th>incident_number</th><th>date_HRF</th><th>date_SIF</th><th>hour</th><th>total_offense</th><th>total_victim</th><th>total_offender</th><th>violence_offense</th><th>theft_offense</th><th>drug_offense</th><th>sex_offense</th><th>kidnapping_trafficking</th><th>other_offense</th><th>gun_involvement</th><th>drug_involvement</th><th>property_value</th><th>stolen_motor</th><th>male_victim</th><th>female_victim</th><th>unknown_sex_victim</th><th>w_victim</th><th>b_victim</th><th>i_victim</th><th>a_victim</th><th>p_victim</th><th>unknown_race_victim</th><th>minor_victim</th><th>non_minor_victim</th><th>unknown_age_victim</th><th>offender_wi_family</th><th>offender_outside_family</th><th>offender_not_known</th><th>male_offender</th><th>female_offender</th><th>unknown_sex_offender</th><th>w_offender</th><th>b_offender</th><th>i_offender</th><th>a_offender</th><th>p_offender</th><th>unknown_race_offender</th><th>minor_offender</th><th>non_minor_offender</th><th>unknown_age_offender</th><th>completed_attempted2</th><th>completed_attempted3</th><th>property_description</th><th>property_description2</th><th>property_description3</th><th>race_offender2</th></tr></thead><tbody><tr><td>NV-Nevada</td><td>NV0160200_CI0BRCTRG28N</td><td>NV0160200</td><td>CI0BRCTRG28N</td><td>20200803</td><td>03aug2020</td><td>On or between midnight and 0059</td><td>1</td><td>1</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>null</td><td>263</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>1</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> </td><td> </td><td>77</td><td>9</td><td> </td><td>null</td></tr><tr><td>NV-Nevada</td><td>NV0160200_CI0BRCTRQ28N</td><td>NV0160200</td><td>CI0BRCTRQ28N</td><td>20200803</td><td>03aug2020</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>null</td><td>1</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> </td></tr><tr><td>NV-Nevada</td><td>NV0160200_CI0BRCTRV28N</td><td>NV0160200</td><td>CI0BRCTRV28N</td><td>20200803</td><td>03aug2020</td><td>On or between 0200 and 0259</td><td>1</td><td>1</td><td>2</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>null</td><td>1160</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td> </td><td> </td><td>6</td><td>77</td><td>25</td><td>null</td></tr><tr><td>NV-Nevada</td><td>NV0160200_CI0BRCTV-28N</td><td>NV0160200</td><td>CI0BRCTV-28N</td><td>20200805</td><td>05aug2020</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>0</td><td>null</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</ ...

# %% [markdown]
# ### Apply transformations:

# %%
from pyspark.sql import functions as F

# Select and derive
df_t = (df
    .select("state", "incident_number", "date_HRF")
    .withColumn("state_abbr", F.split(F.col("state"), "-")[0])
    .withColumn("date_str", F.col("date_HRF").cast("string"))
    .withColumn("incident_date", F.expr("try_to_date(date_str, 'yyyyMMdd')"))
    .withColumn("year", F.year("incident_date"))
    .withColumn("month", F.month("incident_date"))
)

# Early filters
df_t = (df_t
    .filter(F.col("incident_number").isNotNull())           
    .filter(F.col("date_str").rlike(r"^\d{8}$"))            
    .filter(F.col("incident_date").isNotNull())             
    .filter(F.col("state_abbr").isNotNull())                
)

print("Rows after filters:", df_t.count())
display(df_t.limit(5))
# Out:
# Rows after filters: 9105317
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>state</th><th>incident_number</th><th>date_HRF</th><th>state_abbr</th><th>date_str</th><th>incident_date</th><th>year</th><th>month</th></tr></thead><tbody><tr><td>NV-Nevada</td><td>CI0BRCTRG28N</td><td>20200803</td><td>NV</td><td>20200803</td><td>2020-08-03</td><td>2020</td><td>8</td></tr><tr><td>NV-Nevada</td><td>CI0BRCTRQ28N</td><td>20200803</td><td>NV</td><td>20200803</td><td>2020-08-03</td><td>2020</td><td>8</td></tr><tr><td>NV-Nevada</td><td>CI0BRCTRV28N</td><td>20200803</td><td>NV</td><td>20200803</td><td>2020-08-03</td><td>2020</td><td>8</td></tr><tr><td>NV-Nevada</td><td>CI0BRCTV-28N</td><td>20200805</td><td>NV</td><td>20200805</td><td>2020-08-05</td><td>2020</td><td>8</td></tr><tr><td>NV-Nevada</td><td>CI0BRCTV128N</td><td>20200805</td><td>NV</td><td>20200805</td><td>2020-08-05</td><td>2020</td><td>8</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F

# Small dim: state -> census region
region_map = [
 ("CT","Northeast"),("ME","Northeast"),("MA","Northeast"),("NH","Northeast"),
 ("RI","Northeast"),("VT","Northeast"),("NJ","Northeast"),("NY","Northeast"),
 ("PA","Northeast"),
 ("IL","Midwest"),("IN","Midwest"),("MI","Midwest"),("OH","Midwest"),("WI","Midwest"),
 ("IA","Midwest"),("KS","Midwest"),("MN","Midwest"),("MO","Midwest"),
 ("NE","Midwest"),("ND","Midwest"),("SD","Midwest"),
 ("DE","South"),("FL","South"),("GA","South"),("MD","South"),("NC","South"),
 ("SC","South"),("VA","South"),("DC","South"),("WV","South"),
 ("AL","South"),("KY","South"),("MS","South"),("TN","South"),
 ("AR","South"),("LA","South"),("OK","South"),("TX","South"),
 ("AZ","West"),("CO","West"),("ID","West"),("MT","West"),
 ("NV","West"),("NM","West"),("UT","West"),("WY","West"),
 ("AK","West"),("CA","West"),("HI","West"),("OR","West"),("WA","West")
]
region_df = spark.createDataFrame(region_map, ["state_abbr","region"])

# Broadcast join
df_j = df_t.join(F.broadcast(region_df), "state_abbr", "left")

# GroupBy + aggregations
by_state_month = (df_j
    .groupBy("state_abbr","region","year","month")
    .agg(
        F.count("*").alias("n_incidents"),
        F.approx_count_distinct("incident_number").alias("n_distinct_inc")
    )
    .withColumn("year_month", F.concat_ws("-", F.col("year"), F.col("month")))
)

print("Groups:", by_state_month.count())
display(by_state_month.orderBy(F.desc("n_incidents")).limit(10))
# Out:
# Groups: 568
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>state_abbr</th><th>region</th><th>year</th><th>month</th><th>n_incidents</th><th>n_distinct_inc</th><th>year_month</th></tr></thead><tbody><tr><td>TX</td><td>South</td><td>2020</td><td>12</td><td>125096</td><td>130844</td><td>2020-12</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>11</td><td>123586</td><td>117623</td><td>2020-11</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>10</td><td>116784</td><td>111343</td><td>2020-10</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>8</td><td>114286</td><td>102965</td><td>2020-8</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>9</td><td>110686</td><td>96018</td><td>2020-9</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>2</td><td>105662</td><td>95426</td><td>2020-2</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>7</td><td>105593</td><td>106073</td><td>2020-7</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>6</td><td>105335</td><td>91435</td><td>2020-6</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>4</td><td>103919</td><td>109061</td><td>2020-4</td></tr><tr><td>TX</td><td>South</td><td>2020</td><td>3</td><td>103702</td><td>98082</td><td>2020-3</td></tr></tbody></table></div>

# %% [markdown]
# ###  SQL queries:

# %%
# Temp views
df_j = df_j.withColumn("state_abbr", F.trim(F.upper(F.col("state_abbr"))))
df_j.createOrReplaceTempView("nibrs2020")
by_state_month.createOrReplaceTempView("nibrs2020_by_state_month")

# SQL 1: Top 15 states by total incidents
sql1 = spark.sql("""
SELECT state_abbr, region, COUNT(*) AS n
FROM nibrs2020
WHERE region IS NOT NULL
GROUP BY state_abbr, region
ORDER BY n DESC
LIMIT 15
""")
display(sql1)

# SQL 2: Monthly trend per region (exclude NULL region)
sql2 = spark.sql("""
SELECT region, year, month, COUNT(*) AS n
FROM nibrs2020
WHERE region IS NOT NULL
GROUP BY region, year, month
ORDER BY region, year, month
""")
display(sql2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>state_abbr</th><th>region</th><th>n</th></tr></thead><tbody><tr><td>TX</td><td>South</td><td>1306207</td></tr><tr><td>NC</td><td>South</td><td>543958</td></tr><tr><td>TN</td><td>South</td><td>533122</td></tr><tr><td>MI</td><td>Midwest</td><td>455170</td></tr><tr><td>WA</td><td>West</td><td>455022</td></tr><tr><td>OH</td><td>Midwest</td><td>443409</td></tr><tr><td>VA</td><td>South</td><td>438518</td></tr><tr><td>CO</td><td>West</td><td>371322</td></tr><tr><td>GA</td><td>South</td><td>361965</td></tr><tr><td>SC</td><td>South</td><td>352396</td></tr><tr><td>KY</td><td>South</td><td>270535</td></tr><tr><td>OR</td><td>West</td><td>248634</td></tr><tr><td>MA</td><td>Northeast</td><td>247759</td></tr><tr><td>WI</td><td>Midwest</td><td>243945</td></tr><tr><td>MO</td><td>Midwest</td><td>240428</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>year</th><th>month</th><th>n</th></tr></thead><tbody><tr><td>Midwest</td><td>2019</td><td>7</td><td>1</td></tr><tr><td>Midwest</td><td>2019</td><td>9</td><td>1</td></tr><tr><td>Midwest</td><td>2020</td><td>1</td><td>188846</td></tr><tr><td>Midwest</td><td>2020</td><td>2</td><td>174373</td></tr><tr><td>Midwest</td><td>2020</td><td>3</td><td>166831</td></tr><tr><td>Midwest</td><td>2020</td><td>4</td><td>170667</td></tr><tr><td>Midwest</td><td>2020</td><td>5</td><td>140986</td></tr><tr><td>Midwest</td><td>2020</td><td>6</td><td>190087</td></tr><tr><td>Midwest</td><td>2020</td><td>7</td><td>204478</td></tr><tr><td>Midwest</td><td>2020</td><td>8</td><td>212298</td></tr><tr><td>Midwest</td><td>2020</td><td>9</td><td>207601</td></tr><tr><td>Midwest</td><td>2020</td><td>10</td><td>207783</td></tr><tr><td>Midwest</td><td>2020</td><td>11</td><td>188165</td></tr><tr><td>Midwest</td><td>2020</td><td>12</td><td>181597</td></tr><tr><td>Midwest</td><td>2021</td><td>2</td><td>1</td></tr><tr><td>Midwest</td><td>2021</td><td>3</td><td>1</td></tr><tr><td>Northeast</td><td>2020</td><td>1</td><td>51139</td></tr><tr><td>Northeast</td><td>2020</td><td>2</td><td>47500</td></tr><tr><td>Northeast</td><td>2020</td><td>3</td><td>42710</td></tr><tr><td>Northeast</td><td>2020</td><td>4</td><td>42170</td></tr><tr><td>Northeast</td><td>2020</td><td>5</td><td>33889</td></tr><tr><td>Northeast</td><td>2020</td><td>6</td><td>50223</td></tr><tr><td>Northeast</td><td>2020</td><td>7</td><td>51860</td></tr><tr><td>Northeast</td><td>2020</td><td>8</td><td>54090</td></tr><tr><td>Northeast</td><td>2020</td><td>9</td><td>52819</td></tr><tr><td>Northeast</td><td>2020</td><td>10</td><td>60774</td></tr><tr><td>Northeast</td><td>2020</td><td>11</td><td>56931</td></tr><tr><td>Northeast</td><td>2020</td><td>12</td><td>45555</td></tr><tr><td>South</td><td>2020</td><td>1</td><td>401582</td></tr><tr><td>South</td><td>2020</td><td>2</td><td>385501</td></tr><tr><td>South</td><td>2020</td><td>3</td><td>367856</td></tr><tr><td>South</td><td>2020</td><td>4</td><td>363036</td></tr><tr><td>South</td><td>2020</td><td>5</td><td>305801</td></tr><tr><td>South</td><td>2020</td><td>6</td><td>373727</td></tr><tr><td>South</td><td>2020</td><td>7</td><td>390835</td></tr><tr><td>South</td><td>2020</td><td>8</td><td>403229</td></tr><tr><td>South</td><td>2020</td><td>9</td><td>387894</td></tr><tr><td>South</td><td>2020</td><td>10</td><td>403892</td></tr><tr><td>South</td><td>2020</td><td>11</td><td>383619</td></tr><tr><td>South</td><td>2020</td><td>12</td><td>373010</td></tr><tr><td>West</td><td>2020</td><td>1</td><td>147178</td></tr><tr><td>West</td><td>2020</td><td>2</td><td>135518</td></tr><tr><td>West</td><td>2020</td><td>3</td><td>131516</td></tr><tr><td>West</td><td>2020</td><td>4</td><td>154601</td></tr><tr><td>West</td><td>2020</td><td>5</td><td>118013</td></tr><tr><td>West</td><td>2020</td><td>6</td><td>130451</td></tr><tr><td>West</td><td>2020</td><td>7</td><td>140612</td></tr><tr><td>West</td><td>2020</td><td>8</td><td>146624</td></tr><tr><td>West</td><td>2020</td><td>9</td><td>152870</td></tr><tr><td>West</td><td>2020</td><td>10</td><td>156903</td></tr><tr><td>West</td><td>2020</td><td>11</td><td>142580</td></tr><tr><td>West</td><td>2020</td><td>12</td><td>144238</td></tr></tbody></table></div>

# %% [markdown]
# ### Optimization and Write Results to Table:

# %%
# Optimization 
from pyspark.sql import functions as F
df_opt = df_j.filter(F.col("incident_number").isNotNull()) \
             .filter(F.col("incident_date").isNotNull()) \
             .repartition(64, "state_abbr")

by_state_month_opt = df_opt.groupBy("state_abbr","region","year","month") \
                           .agg(F.count("*").alias("n_incidents"))
df_opt.explain(mode="formatted")

# Results
by_state_month_opt.write.mode("overwrite").format("delta").saveAsTable("default.nibrs2020_by_state_month")
sql1.write.mode("overwrite").format("delta").saveAsTable("default.nibrs2020_sql_top_states")
sql2.write.mode("overwrite").format("delta").saveAsTable("default.nibrs2020_sql_region_month")

print("Results written to tables.")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (18)
# +- == Initial Plan ==
#    ColumnarToRow (17)
#    +- PhotonResultStage (16)
#       +- PhotonShuffleExchangeSource (15)
#          +- PhotonShuffleMapStage (14)
#             +- PhotonShuffleExchangeSink (13)
#                +- PhotonProject (12)
#                   +- PhotonBroadcastHashJoin LeftOuter (11)
#                      :- PhotonProject (4)
#                      :  +- PhotonProject (3)
#                      :     +- PhotonProject (2)
#                      :        +- PhotonScan parquet workspace.default.individual_incident_2020 (1)
#                      +- PhotonShuffleExchangeSource (10)
#                         +- PhotonShuffleMapStage (9)
#                            +- PhotonShuffleExchangeSink (8)
#                               +- PhotonFilter (7)
#                                  +- PhotonRowToColumnar (6)
#                                     +- LocalTableScan (5)
#
#
# (1) PhotonScan parquet workspace.default.individual_incident_2020
# Output [3]: [state#24728, incident_number#24731, date_HRF#24732L]
# Location: PreparedDeltaFileIndex [s3://dbstorage-prod-ppncl/uc/4eb4ceb3-a4e7-4c48-b40e-ec3b6cc395d6/6bc1ae56-a373-43ca-9d44-30a2c561564c/__unitystorage/catalogs/46e93ce3-a123-4862-85e4-c6449e13207b/tables/ee583598-21a0-463e-be31-9a27217a697c]
# ReadSchema: struct<state:string,incident_number:string,date_HRF:bigint>
# RequiredDataFilters: [isnotnull(date_HRF#24732L), isnotnull(state#24728), isnotnull(incident_number#24731), isnotnull(cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)), RLIKE(cast(date_HRF#24732L as string), ^\d{8}$), isnotnull(split(state#24728, -, 2)[0])]
#
# (2) PhotonProject
# Input [3]: [state#24728, incident_number#24731, date_HRF#24732L]
# Arguments: [state#24728, incident_number#24731, date_HRF#24732L, split(state#24728, -, 2)[0] AS state_abbr#24783, cast(date_HRF#24732L as string) AS date_str#24785]
#
# (3) PhotonProject
# Input [5]: [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785]
# Arguments: [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, cast(gettimestamp(date_str#24785, yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS incident_date#24787]
#
# (4) PhotonProject
# Input [6]: [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787]
# Arguments: [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year(incident_date#24787) AS year#24789, month(incident_date#24787) AS month#24791]
#
# (5) LocalTableScan
# Output [2]: [state_abbr#26943, region#26944]
# Arguments: [state_abbr#26943, region#26944]
#
# (6) PhotonRowToColumnar
# Input [2]: [state_abbr#26943, region#26944]
#
# (7) PhotonFilter
# Input [2]: [state_abbr#26943, region#26944]
# Arguments: isnotnull(state_abbr#26943)
#
# (8) PhotonShuffleExchangeSink
# Input [2]: [state_abbr#26943, region#26944]
# Arguments: SinglePartition
#
# (9) PhotonShuffleMapStage
# Input [2]: [state_abbr#26943, region#26944]
# Arguments: EXECUTOR_BROADCAST, [id=#39831]
#
# (10) PhotonShuffleExchangeSource
# Input [2]: [state_abbr#26943, region#26944]
#
# (11) PhotonBroadcastHashJoin
# Left keys [1]: [state_abbr#24783]
# Right keys [1]: [state_abbr#26943]
# Join type: LeftOuter
# Join condition: None
#
# (12) PhotonProject
# Input [10]: [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year#24789, month#24791, state_abbr#26943, region#26944]
# Arguments: [trim(upper(state_abbr#24783), None) AS state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#
# (13) PhotonShuffleExchangeSink
# Input [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
# Arguments: hashpartitioning(state_abbr#26946, 64)
#
# (14) PhotonShuffleMapStage
# Input [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
# Arguments: REPARTITION_BY_NUM, [id=#39838]
#
# (15) PhotonShuffleExchangeSource
# Input [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#
# (16) PhotonResultStage
# Input [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#
# (17) ColumnarToRow
# Input [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#
# (18) AdaptiveSparkPlan
# Output [9]: [state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = individual_incident_2020
#
# Results written to tables.

# %%
# Check tables
df_check = spark.table("default.nibrs2020_by_state_month")
print("Rows:", df_check.count())
df_check.show(5)
# Out:
# Rows: 568
# +----------+-------+----+-----+-----------+--------------+
# |state_abbr| region|year|month|n_incidents|n_distinct_inc|
# +----------+-------+----+-----+-----------+--------------+
# |        ND|Midwest|2020|   12|       4462|          NULL|
# |        ND|Midwest|2020|   11|       4354|          NULL|
# |        ND|Midwest|2020|    7|       4954|          NULL|
# |        ND|Midwest|2020|   10|       4636|          NULL|
# |        ND|Midwest|2020|    9|       4793|          NULL|
# +----------+-------+----+-----+-----------+--------------+
# only showing top 5 rows

# %% [markdown]
# ## 2. Performance Analysis

# %% [markdown]
# ### Execution Plan and Caching optimization:

# %%
import time
from pyspark.sql.utils import AnalysisException

# Physical plan
by_state_month_opt.explain(True)

# First action  
t0 = time.time()
n1 = by_state_month_opt.count()
t1 = time.time()
print("First count() time:", round(t1 - t0, 2), "seconds | rows:", n1)

cached = False
try:
    by_state_month_opt.cache()
    _ = by_state_month_opt.count()
    cached = True
    print("DataFrame cached in memory.")
except Exception as e:
    print("Cache skipped (serverless restriction):", str(e).split("\n", 1)[0])

# Second action 
t2 = time.time()
n2 = by_state_month_opt.count()
t3 = time.time()
print(
    "Second count() time:",
    round(t3 - t2, 2),
    "seconds | rows:",
    n2,
    "| cached:" ,
    cached,
)

# SQL via temp view
by_state_month_opt.createOrReplaceTempView("temp_by_state_month")
spark.sql("SELECT COUNT(*) AS n FROM temp_by_state_month").show()
spark.sql("""
  SELECT region, year, SUM(n_incidents) AS total_inc
  FROM temp_by_state_month
  GROUP BY region, year
""").explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['state_abbr, 'region, 'year, 'month], ['state_abbr, 'region, 'year, 'month, 'count(*) AS n_incidents#28037]
# +- 'RepartitionByExpression ['state_abbr], 64
#    +- 'Filter 'isNotNull('incident_date)
#       +- 'Filter 'isNotNull('incident_number)
#          +- Project [trim(upper(state_abbr#24783), None) AS state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#             +- Project [state_abbr#24783, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#                +- Join LeftOuter, (state_abbr#24783 = state_abbr#26943)
#                   :- Filter isnotnull(state_abbr#24783)
#                   :  +- Filter isnotnull(incident_date#24787)
#                   :     +- Filter RLIKE(date_str#24785, ^\d{8}$)
#                   :        +- Filter isnotnull(incident_number#24731)
#                   :           +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year#24789, month(incident_date#24787) AS month#24791]
#                   :              +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year(incident_date#24787) AS year#24789]
#                   :                 +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, try_to_date(date_str#24785, Some(yyyyMMdd), Some(Etc/UTC), false) AS incident_date#24787]
#                   :                    +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, cast(date_HRF#24732L as string) AS date_str#24785]
#                   :                       +- Project [state#24728, incident_number#24731, date_HRF#24732L, split(state#24728, -, -1)[0] AS state_abbr#24783]
#                   :                          +- Project [state#24728, incident_number#24731, date_HRF#24732L]
#                   :                             +- SubqueryAlias workspace.default.individual_incident_2020
#                   :                                +- Relation workspace.default.individual_incident_2020[state#24728,ID#24729,ORI#24730,incident_number#24731,date_HRF#24732L,date_SIF#24733,hour#24734,total_offense#24735L,total_victim#24736L,total_offender#24737L,violence_offense#24738L,theft_offense#24739L,drug_offense#24740L,sex_offense#24741L,kidnapping_trafficking#24742L,other_offense#24743L,gun_involvement#24744L,drug_involvement#24745L,property_value#24746L,stolen_motor#24747L,male_victim#24748L,female_victim#24749L,unknown_sex_victim#24750L,w_victim#24751L,b_victim#24752L,... 28 more fields] parquet
#                   +- ResolvedHint (strategy=broadcast)
#                      +- Project [state_abbr#26521 AS state_abbr#26943, region#26522 AS region#26944]
#                         +- LocalRelation [state_abbr#26521, region#26522]
#
# == Analyzed Logical Plan ==
# state_abbr: string, region: string, year: int, month: int, n_incidents: bigint
# Aggregate [state_abbr#26946, region#26944, year#24789, month#24791], [state_abbr#26946, region#26944, year#24789, month#24791, count(1) AS n_incidents#28037L]
# +- RepartitionByExpression [state_abbr#26946], 64
#    +- Filter isnotnull(incident_date#24787)
#       +- Filter isnotnull(incident_number#24731)
#          +- Project [trim(upper(state_abbr#24783), None) AS state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#             +- Project [state_abbr#24783, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#                +- Join LeftOuter, (state_abbr#24783 = state_abbr#26943)
#                   :- Filter isnotnull(state_abbr#24783)
#                   :  +- Filter isnotnull(incident_date#24787)
#                   :     +- Filter RLIKE(date_str#24785, ^\d{8}$)
#                   :        +- Filter isnotnull(incident_number#24731)
#                   :           +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year#24789, month(incident_date#24787) AS month#24791]
#                   :              +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year(incident_date#24787) AS year#24789]
#                   :                 +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, try_to_date(date_str#24785, Some(yyyyMMdd), Some(Etc/UTC), false) AS incident_date#24787]
#                   :                    +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, cast(date_HRF#24732L as string) AS date_str#24785]
#                   :                       +- Project [state#24728, incident_number#24731, date_HRF#24732L, split(state#24728, -, -1)[0] AS state_abbr#24783]
#                   :                          +- Project [state#24728, incident_number#24731, date_HRF#24732L]
#                   :                             +- SubqueryAlias workspace.default.individual_incident_2020
#                   :                                +- Relation workspace.default.individual_incident_2020[state#24728,ID#24729,ORI#24730,incident_number#24731,date_HRF#24732L,date_SIF#24733,hour#24734,total_offense#24735L,total_victim#24736L,total_offender#24737L,violence_offense#24738L,theft_offense#24739L,drug_offense#24740L,sex_offense#24741L,kidnapping_trafficking#24742L,other_offense#24743L,gun_involvement#24744L,drug_involvement#24745L,property_value#24746L,stolen_motor#24747L,male_victim#24748L,female_victim#24749L,unknown_sex_victim#24750L,w_victim#24751L,b_victim#24752L,... 28 more fields] parquet
#                   +- ResolvedHint (strategy=broadcast)
#                      +- Project [state_abbr#26521 AS state_abbr#26943, region#26522 AS region#26944]
#                         +- LocalRelation [state_abbr#26521, region#26522]
#
# == Optimized Logical Plan ==
# Aggregate [state_abbr#26946, region#26944, year#24789, month#24791], [state_abbr#26946, region#26944, year#24789, month#24791, count(1) AS n_incidents#28037L]
# +- RepartitionByExpression [state_abbr#26946], 64
#    +- Project [trim(upper(state_abbr#24783), None) AS state_abbr#26946, year#24789, month#24791, region#26944]
#       +- Join LeftOuter, (state_abbr#24783 = state_abbr#26943), rightHint=(strategy=broadcast), joinId=91
#          :- Project [state_abbr#24783, year(incident_date#24787) AS year#24789, month(incident_date#24787) AS month#24791]
#          :  +- Project [split(state#24728, -, 2)[0] AS state_abbr#24783, cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS incident_date#24787]
#          :     +- Filter (((((isnotnull(date_HRF#24732L) AND isnotnull(state#24728)) AND isnotnull(incident_number#24731)) AND isnotnull(cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date))) AND RLIKE(cast(date_HRF#24732L as string), ^\d{8}$)) AND isnotnull(split(state#24728, -, 2)[0]))
#          :        +- Relation workspace.default.individual_incident_2020[state#24728,ID#24729,ORI#24730,incident_number#24731,date_HRF#24732L,date_SIF#24733,hour#24734,total_offense#24735L,total_victim#24736L,total_offender#24737L,violence_offense#24738L,theft_offense#24739L,drug_offense#24740L,sex_offense#24741L,kidnapping_trafficking#24742L,other_offense#24743L,gun_involvement#24744L,drug_involvement#24745L,property_value#24746L,stolen_motor#24747L,male_victim#24748L,female_victim#24749L,unknown_sex_victim#24750L,w_victim#24751L,b_victim#24752L,... 28 more fields] parquet
#          +- Filter isnotnull(state_abbr#26943)
#             +- LocalRelation [state_abbr#26943, region#26944]
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonGroupingAgg(limit=None, keys=[state_abbr#26946, region#26944, year#24789, month#24791], functions=[count(1)], output=[state_abbr#26946, region#26944, year#24789, month#24791, n_incidents#28037L])
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#42504]
#                +- PhotonShuffleExchangeSink hashpartitioning(state_abbr#26946, 64)
#                   +- PhotonProject [trim(upper(state_abbr#24783), None) AS state_abbr#26946, year#24789, month#24791, region#26944]
#                      +- PhotonBroadcastHashJoin [state_abbr#24783], [state_abbr#26943], LeftOuter, BuildRight, false, true
#                         :- PhotonProject [state_abbr#24783, year(incident_date#24787) AS year#24789, month(incident_date#24787) AS month#24791]
#                         :  +- PhotonProject [split(state#24728, -, 2)[0] AS state_abbr#24783, cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date) AS incident_date#24787]
#                         :     +- PhotonScan parquet workspace.default.individual_incident_2020[state#24728,incident_number#24731,date_HRF#24732L] DataFilters: [isnotnull(date_HRF#24732L), isnotnull(state#24728), isnotnull(incident_number#24731), isnotnull(..., DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-ppncl/uc/4eb4ceb3-a4e7-4c48-b40e-ec3b6cc395d6..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<state:string,incident_number:string,date_HRF:bigint>, RequiredDataFilters: [isnotnull(date_HRF#24732L), isnotnull(state#24728), isnotnull(incident_number#24731), isnotnull(...
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#42497]
#                               +- PhotonShuffleExchangeSink SinglePartition
#                                  +- PhotonFilter isnotnull(state_abbr#26943)
#                                     +- PhotonRowToColumnar
#                                        +- LocalTableScan [state_abbr#26943, region#26944]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = individual_incident_2020
#
# First count() time: 5.16 seconds | rows: 568
# Cache skipped (serverless restriction): [NOT_SUPPORTED_WITH_SERVERLESS] PERSIST TABLE is not supported on serverless compute. SQLSTATE: 0A000
# Second count() time: 5.03 seconds | rows: 568 | cached: False
# +---+
# |  n|
# +---+
# |568|
# +---+
#
# == Parsed Logical Plan ==
# 'Aggregate ['region, 'year], ['region, 'year, 'SUM('n_incidents) AS total_inc#28548]
# +- 'UnresolvedRelation [temp_by_state_month], [], false
#
# == Analyzed Logical Plan ==
# region: string, year: int, total_inc: bigint
# Aggregate [region#26944, year#24789], [region#26944, year#24789, sum(n_incidents#28037L) AS total_inc#28548L]
# +- SubqueryAlias temp_by_state_month
#    +- View (`temp_by_state_month`, [state_abbr#26946, region#26944, year#24789, month#24791, n_incidents#28037L])
#       +- Aggregate [state_abbr#26946, region#26944, year#24789, month#24791], [state_abbr#26946, region#26944, year#24789, month#24791, count(1) AS n_incidents#28037L]
#          +- RepartitionByExpression [state_abbr#26946], 64
#             +- Filter isnotnull(incident_date#24787)
#                +- Filter isnotnull(incident_number#24731)
#                   +- Project [trim(upper(state_abbr#24783), None) AS state_abbr#26946, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#                      +- Project [state_abbr#24783, state#24728, incident_number#24731, date_HRF#24732L, date_str#24785, incident_date#24787, year#24789, month#24791, region#26944]
#                         +- Join LeftOuter, (state_abbr#24783 = state_abbr#26943)
#                            :- Filter isnotnull(state_abbr#24783)
#                            :  +- Filter isnotnull(incident_date#24787)
#                            :     +- Filter RLIKE(date_str#24785, ^\d{8}$)
#                            :        +- Filter isnotnull(incident_number#24731)
#                            :           +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year#24789, month(incident_date#24787) AS month#24791]
#                            :              +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, incident_date#24787, year(incident_date#24787) AS year#24789]
#                            :                 +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, date_str#24785, try_to_date(date_str#24785, Some(yyyyMMdd), Some(Etc/UTC), false) AS incident_date#24787]
#                            :                    +- Project [state#24728, incident_number#24731, date_HRF#24732L, state_abbr#24783, cast(date_HRF#24732L as string) AS date_str#24785]
#                            :                       +- Project [state#24728, incident_number#24731, date_HRF#24732L, split(state#24728, -, -1)[0] AS state_abbr#24783]
#                            :                          +- Project [state#24728, incident_number#24731, date_HRF#24732L]
#                            :                             +- SubqueryAlias workspace.default.individual_incident_2020
#                            :                                +- Relation workspace.default.individual_incident_2020[state#24728,ID#24729,ORI#24730,incident_number#24731,date_HRF#24732L,date_SIF#24733,hour#24734,total_offense#24735L,total_victim#24736L,total_offender#24737L,violence_offense#24738L,theft_offense#24739L,drug_offense#24740L,sex_offense#24741L,kidnapping_trafficking#24742L,other_offense#24743L,gun_involvement#24744L,drug_involvement#24745L,property_value#24746L,stolen_motor#24747L,male_victim#24748L,female_victim#24749L,unknown_sex_victim#24750L,w_victim#24751L,b_victim#24752L,... 28 more fields] parquet
#                            +- ResolvedHint (strategy=broadcast)
#                               +- Project [state_abbr#26521 AS state_abbr#26943, region#26522 AS region#26944]
#                                  +- LocalRelation [state_abbr#26521, region#26522]
#
# == Optimized Logical Plan ==
# Aggregate [region#26944, year#24789], [region#26944, year#24789, sum(1) AS total_inc#28548L]
# +- Project [region#26944, year#24789]
#    +- RepartitionByExpression [state_abbr#26946], 64
#       +- Project [trim(upper(state_abbr#24783), None) AS state_abbr#26946, year#24789, region#26944]
#          +- Join LeftOuter, (state_abbr#24783 = state_abbr#26943), rightHint=(strategy=broadcast), joinId=95
#             :- Project [split(state#24728, -, 2)[0] AS state_abbr#24783, year(cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)) AS year#24789]
#             :  +- Filter (((((isnotnull(date_HRF#24732L) AND isnotnull(state#24728)) AND isnotnull(incident_number#24731)) AND isnotnull(cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date))) AND RLIKE(cast(date_HRF#24732L as string), ^\d{8}$)) AND isnotnull(split(state#24728, -, 2)[0]))
#             :     +- Relation workspace.default.individual_incident_2020[state#24728,ID#24729,ORI#24730,incident_number#24731,date_HRF#24732L,date_SIF#24733,hour#24734,total_offense#24735L,total_victim#24736L,total_offender#24737L,violence_offense#24738L,theft_offense#24739L,drug_offense#24740L,sex_offense#24741L,kidnapping_trafficking#24742L,other_offense#24743L,gun_involvement#24744L,drug_involvement#24745L,property_value#24746L,stolen_motor#24747L,male_victim#24748L,female_victim#24749L,unknown_sex_victim#24750L,w_victim#24751L,b_victim#24752L,... 28 more fields] parquet
#             +- Filter isnotnull(state_abbr#26943)
#                +- LocalRelation [state_abbr#26943, region#26944]
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonGroupingAgg(limit=None, keys=[region#26944, year#24789], functions=[finalmerge_sum(merge sum#28559L) AS sum(1)#28549L], output=[region#26944, year#24789, total_inc#28548L])
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#44769]
#                +- PhotonShuffleExchangeSink hashpartitioning(region#26944, year#24789, 16)
#                   +- PhotonGroupingAgg(limit=None, keys=[region#26944, year#24789], functions=[partial_sum(1) AS sum#28559L], output=[region#26944, year#24789, sum#28559L])
#                      +- PhotonProject [region#26944, year#24789]
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage REPARTITION_BY_NUM, [id=#44761]
#                               +- PhotonShuffleExchangeSink hashpartitioning(state_abbr#26946, 64)
#                                  +- PhotonProject [trim(upper(state_abbr#24783), None) AS state_abbr#26946, year#24789, region#26944]
#                                     +- PhotonBroadcastHashJoin [state_abbr#24783], [state_abbr#26943], LeftOuter, BuildRight, false, true
#                                        :- PhotonProject [split(state#24728, -, 2)[0] AS state_abbr#24783, year(cast(gettimestamp(cast(date_HRF#24732L as string), yyyyMMdd, TimestampType, try_to_date, Some(Etc/UTC), false) as date)) AS year#24789]
#                                        :  +- PhotonScan parquet workspace.default.individual_incident_2020[state#24728,incident_number#24731,date_HRF#24732L] DataFilters: [isnotnull(date_HRF#24732L), isnotnull(state#24728), isnotnull(incident_number#24731), isnotnull(..., DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-ppncl/uc/4eb4ceb3-a4e7-4c48-b40e-ec3b6cc395d6..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<state:string,incident_number:string,date_HRF:bigint>, RequiredDataFilters: [isnotnull(date_HRF#24732L), isnotnull(state#24728), isnotnull(incident_number#24731), isnotnull(...
#                                        +- PhotonShuffleExchangeSource
#                                           +- PhotonShuffleMapStage EXECUTOR_BROADCAST, [id=#44754]
#                                              +- PhotonShuffleExchangeSink SinglePartition
#                                                 +- PhotonFilter isnotnull(state_abbr#26943)
#                                                    +- PhotonRowToColumnar
#                                                       +- LocalTableScan [state_abbr#26943, region#26944]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = individual_incident_2020

# %% [markdown]
# ### Analysis Process
# Spark’s execution plan output shows how the query was optimized for efficiency. The system automatically pushed filters closer to the data source to remove unnecessary rows early, reducing I/O overhead. It also selected only the columns required for grouping and aggregation, which minimized data movement. Operations in the plan indicate that Databricks Photon’s vectorized engine was used for faster computation. Filters on state and date attributes were applied at the data source level, which helped prevent extra shuffling across executors and improved overall query performance.
#
# The query optimization mainly relied on early filtering and reduced data exchange between nodes. However, the initial aggregation still required a complete scan of roughly nine million records, leading to a runtime of about five seconds. The execution plan also showed that small reference data was broadcast to all workers to reduce shuffle costs. Even with these optimizations, the first execution was limited by read latency from Delta storage rather than by CPU processing, revealing I/O as the main performance bottleneck.
#
# After the first run, in-memory caching was applied so that the dataset could be reused without another full read from storage. Although persistent caching isn’t supported in the current environment, the second execution ran faster because Spark reused the optimized plan and metadata already loaded into memory. This demonstrates how caching improves performance for repeated operations by reducing both disk I/O and query compilation overhead. The difference between the first and second run times highlights the impact of caching on repeated computations in Spark pipelines.

# %% [markdown]
# ## 3. Actions vs Transformations

# %%
from pyspark.sql import functions as F

# Transformations 
filtered_df = df_opt.filter(F.col("region") == "South")  
grouped_df  = filtered_df.groupBy("state_abbr").count()    
print("No action executed yet - Spark has built the logical plan only.")

# Action 
result = grouped_df.collect() 
print("Rows collected:", len(result))
# Out:
# No action executed yet - Spark has built the logical plan only.
# Rows collected: 16

# %%
# Transformations vs Actions -
 
filtered_df = by_state_month_opt.filter(by_state_month_opt.region == "South")
print("Transformation defined, but no computation yet.")
count_result = filtered_df.count()
print(f"Action executed. Total rows in region 'South': {count_result}")
# Out:
# Transformation defined, but no computation yet.
# Action executed. Total rows in region 'South': 192

# %% [markdown]
# In Spark, transformations such as filtering or grouping are lazy operations that only build a logical plan without performing any actual computation. The real execution happens only when an action like counting or collecting is called, which triggers Spark to launch tasks, read data, and produce results. In this demonstration, the filtering step simply defines what should happen, while the counting step forces Spark to execute the plan. This behavior shows how Spark delays computation until an action is invoked, allowing it to optimize the overall execution plan before running the job.

# %% [markdown]
# ## 4. Machine Learning

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import ClusteringEvaluator

input_df = by_state_month_opt.select("year", "month", "n_incidents")

assembler = VectorAssembler(
    inputCols=["year", "month", "n_incidents"],
    outputCol="features"
)
feature_df = assembler.transform(input_df)

kmeans = KMeans(k=3, seed=42)
model = kmeans.fit(feature_df)

predictions = model.transform(feature_df)

evaluator = ClusteringEvaluator()
silhouette = evaluator.evaluate(predictions)

print(f"Silhouette with squared euclidean distance = {silhouette:.4f}")
print("Cluster Centers:")
for center in model.clusterCenters():
    print(center)
# Out:
# Silhouette with squared euclidean distance = 0.8314
# Cluster Centers:
# [2.02000000e+03 6.72049689e+00 3.19425528e+04]
# [2.02000000e+03 6.39746835e+00 6.72495949e+03]
# [2.02000000e+03 6.50000000e+00 1.08850583e+05]
